# %% [markdown]
# ## Calcolo del Calore specifico di Debye
#
# Nella simulazione si calcola l'integrale di Debye

# %%
# %matplotlib notebook
import matplotlib.pyplot as P
import numpy as np
# De Sorbo data uses cal/g-atom/K

Td = np.array([17.40, 23.12, 25.26, 27.22, 29.47, 36.53, 31.00, 33.08, 38.31, 41.63, 44.07, 52.18, 55.20, 62.54, 66.40, 69.30, 73.20, 74.91, 76.16, 79.57, 82.36, 87.34, 93.70, 100.33, 106.71, 112.68, 118.02, 123.42, 129.11, 134.78, 141.28, 146.55, 152.64, 158.46, 164.10, 169.53, 175.06, 179.78, 185.29, 191.11, 196.00, 200.29, 205.77, 210.85, 213.09, 216.67, 226.77, 231.79, 236.78, 241.93, 246.39, 250.76, 257.11, 265.99, 271.55, 277.48, 281.26, 285.22, 290.80, 293.51, 299.07, 300.57])


Cd = np.array([0.0001, 0.0004, 0.0015, 0.0014, 0.0020, 0.0024, 0.0021, 0.0020, 0.0086, 0.0032, 0.0039, 0.0054, 0.0068, 0.0107, 0.0127, 0.0156, 0.0178, 0.0204, 0.0222, 0.0260, 0.0307, 0.0356, 0.0478, 0.0576, 0.0758, 0.0932, 0.105, 0.124, 0.145, 0.168, 0.197, 0.223, 0.255, 0.286, 0.325, 0.349, 0.377, 0.418, 0.454, 0.497, 0.532, 0.561, 0.606, 0.643, 0.660, 0.694, 0.785, 0.812, 0.864, 0.914, 0.945, 0.989, 1.048, 1.142, 1.200, 1.252, 1.295, 1.341, 1.379, 1.407, 1.469, 1.481])*4.184
 
#T = np.array([222.4,262.4,283.7,306.4,331.3,358.5,413.0,479.2,520.0,879.7,1079.7,1258.0])
#CE = np.array([0.762,1.146,1.354,1.582,1.838,2.118,2.661,3.280,3.631,5.290,5.387,5.507])*4.184
# Einstein uses calories
T = np.linspace(10.,310.,311)
R = 8.3144
fig,ax = P.subplots(figsize=(6,4))
ax.plot(Td,Cd,'o',label='De Sorbo J. Chem. Phys. 21, 876')
#ax.plot(T,3*R+T-T,'--')
for theta in np.arange(1230.,1431.,100.):
    bhw = theta/T
    C = 3*R*(bhw)**2*np.exp(bhw)/(np.exp(bhw)-1)**2
# bhw = beta hbar wE 
    ax.plot(T,C,label=r'$T_E$ = {:.0f} K'.format(theta))
ax.set_xlabel('T [K]')
ax.set_ylabel('C [J/mol]')
ax.set_ylim(0,6)
ax.set_xlim(0,310)
ax.legend()
P.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# I casi di interesse sono quelli di elevanta densità di fermioni. Notare che l'energia di Fermi, $E_F =\mu(T=0)$, per i fermioni non interagenti di energia $\epsilon = \hbar^2 k^2/2m$, è proporzionale alla loro densità alla potenza 2/3,
#
# $$ E_F = \frac {\hbar^2} {2m} (3\pi^2 n)^{\frac 2 3} $$
#
# e diventa molto grande per la densità di un elettrone per atomo (ad esempio per il rame  metallico $E_F/k_B = 60 000$, ossia nelle unità della simulazione mu = 300 a temperatura ambiente).
#
# Il caso mu = 3, curva rossa, corrisponde per il rame alla temperatura di 20 000 K
