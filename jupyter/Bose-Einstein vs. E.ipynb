# %% [markdown]
# # Bose-Einstein vs. E

# %%
# %matplotlib notebook
# parola magica
import numpy as np
# le funzioni matematiche
import matplotlib.pyplot as P
# le funzioni grafiche
def n(E,mu,kBT):
    # questa è la definizione di una routine (funzione), il testo che segue è spostato a dx
    # il carattere : inizia la definizione della routine 
    # E e mu sono due valori in ingresso
    # il valore in uscita è scritto dopo il comando return qui sotto
    # il cancelletto inizia il commento
    return 1./(np.exp((E-mu)/kBT)-1)
# fine della funzione, ritorna a sn. D'ora in avanti n(2,1) calcola la funzione in questi due punti
# Se l'ingresso è un vettore E numpy calcola come matlab l'intera funzione vettoriale 
# kT=1
fig,ax = P.subplots(figsize=(5,4))
# definisce una figura fig e un set di assi ax
mu1,mu2 = 0,-0.1
kBTT = np.logspace(-0.6,0.6,8)
E = np.linspace(0.01,1.,1000)
# funzione di numpy, per vedere cosa fa digitare numpy linspace in google
for kBT in kBTT:
    # anche i loop richiedono : e lo spostamento a dx
    ax.plot(E,n(E,mu1,kBT),label='{:.1f}'.format(kBT))
    ax.plot(E,n(E,mu2,kBT),'--',color=P.gca().lines[-1].get_color()) # stesso colore tratteggiata
    # genera il plot di una curva 
    # il loop produce tanti plot quanti i valori di mus e finisce con lo spostamento a sn
ax.set_xlabel(r'$k_BT$')
# aggiunge l'etichetta dell'asse x, v. ad es.  pyplot x label
ax.set_ylabel(r'n$_B$(E,$\mu$,T)')
# idem y
ax.legend(title=r'$\mu = 0, k_BT$',loc='right')
# aggiunge la legenda, v. ad es.  pyplot legend
P.show()
# chiude sempre questi file, e produce il grafico qui sotto
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# Questa è una riga di testo finale ottenuta selezionando Markdown nel pulldown in cima alla pagina
#
# Selezionando Code il testo verrebbe interpretato come commandi python
